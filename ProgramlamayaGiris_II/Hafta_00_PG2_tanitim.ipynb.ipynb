# %% [markdown]
# # Programlamaya Giriş-II
#
# Programlamaya Giriş-I dersinin içeriklerine ulaşmak için [Tıklayınız](https://classroom.google.com/c/NjMwNzU0NDYyOTA2?cjc=xgs6657)

# %% [markdown]
# ### Hafta 1: Temel Konuların Tekrarı ve Alıştırmalar - Bölüm 1
#   - Python programlama dilinde temel kavramların tekrarı: Değişkenler, veri tipleri, temel operatörler
#   - String işlemleri
#   - Standart girdi ve çıktı işlemleri
#
# ### Hafta 2: Temel Konuların Tekrarı ve Alıştırmalar - Bölüm 2
#   - Koşullu ifadeler (if, else, elif)
#   - For ve While döngüleri
#   - Kısa alıştırmalar ve örneklerle pekiştirme
#
# ### Hafta 3: Temel Konuların Tekrarı ve Alıştırmalar - Bölüm 2
#   - Fonksiyonlar, parametreler ve geri dönüş değerleri
#   - Listeler, demetler ve sözlükler: Veri yapılarının tekrarı ve ileri düzey kullanımları
#   - Kısa alıştırmalar ve örneklerle pekiştirme
#
# ### Hafta 4: İleri Düzey Fonksiyonlar - Bölüm 1
# - Lambda Fonksiyonları
# - İç içe geçmiş Listeler
# - Liste Üreteçleri (List Comprehensions)
# - Küme Üreteçleri (Set Comprehensions)
# - Sözlük Üreteçleri (Dictionary Comprehensions)
#
# ### Hafta 5: İleri Düzey Fonksiyonlar - Bölüm 2
# - İç İçe (Nested) Fonksiyonlar
# - Kapanışlar (closures)
#
# ### Hafta 6: Modüller
# - Python'da Modüllerin Kullanımı
# - Hazır Modüller, Modüllerin İçe Aktarılması
# - Kendi Tanımladığımız Modüller
#
# ### Hafta 7: Recursive Fonksiyonlar
# - Özyinelemeli (Recursive) Fonksiyonlar
# - Dekoratörler (Decorators)
# - Dekoratör Fabrikası (Decorator Factory)
#
# ### Hafta 8: Vize Haftası
# - **İlk 7 haftanın konularını ve Programlamaya Giriş-I dersinin tüm konularını** kapsayan vize sınavı
#
# ### Hafta 9: Dosya İşlemleri
# - Dosya açma, okuma, yazma ve güncelleme işlemleri
#
# ### Hafta 10: Hata Yakalama ve İstisna Yönetimi
# - Hata türleri
# - Hatalar ve İstisnalar (Error and Exceptions)
# - `try`, `except`,`else`,`finally` blokları
# - Hata Fırlatma (İstisna Oluşturma) (Raise an exception)
#
# ### Hafta 11: Nesne Yönelimli Programlama (NYP) - Bölüm 1
# - NYP'nin temel kavramları: Sınıf, nesne, metod, encapsulation
# - Python'da sınıf tanımlama ve nesne oluşturma
# - Basit nesne tabanlı programlama örnekleri
#
# ### Hafta 12: Nesne Yönelimli Programlama (NYP)  - Bölüm 2
# - NYP'nin temel kavramları: Sınıf, nesne, metod, encapsulation
# - Python'da sınıf tanımlama ve nesne oluşturma
# - Basit nesne tabanlı programlama örnekleri
#
# ### Hafta 13: NYP - İleri Konular  - Bölüm 2
# - Kalıtım, polimorfizm ve ~soyutlama~
# - Özel metotlar, sınıf metotları ve statik metotlar
#
# ### Hafta 14:
# - Veritabanı (DataBase, DB) Nedir ve Neden Kullanılır?
# - SQLite Nedir?
# - Temel SQL Komutları
# - SQLite  Veritabanı (Bağlantısı) Oluşturma
#
# ### Hafta 15-16: Final Sınavı
# - **Programlamaya Giriş-I ve II derslerinin tüm konularını kapsayan Final Sınavı**
# - Dersin Kapanışı ve Değerlendirme
