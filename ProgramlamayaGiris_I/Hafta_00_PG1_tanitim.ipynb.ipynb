# %% [markdown]
# # Programlamaya Giriş - 1
# **Dersin Amacı:**
#
# "Programlamaya Giriş - 1" dersi, yazılım mühendisliği alanına yeni başlayan öğrencilere programlamanın temel kavramlarını ve Python programlama dilini tanıtmayı amaçlar. Dersin odak noktası, öğrencilere sıfırdan başlayarak bilgisayar bilimi ve algoritma temellerini sağlam bir şekilde anlatmak ve pratik Python becerileri kazandırmaktır. Ders, öğrencilerin algoritma geliştirme, problem çözme yeteneklerini geliştirmeyi ve yazılım geliştirmeye yönelik temel yapıtaşlarını sağlam bir temel üzerine kurmayı hedefler.
#
# (**Course Objective:** The "Introduction to Programming - 1" course aims to introduce the fundamental concepts of programming and the Python programming language to students new to the field of software engineering. The focus of the course is to thoroughly explain the basics of computer science and algorithms to students starting from scratch and to equip them with practical Python skills. The course is designed to enhance students' abilities in algorithm development and problem-solving, and to lay a solid foundation for software development.)
#
#
# **Dersin İçeriği:**
#
# "Programlamaya Giriş - 1" dersi, öğrencilere bilgisayar bilimlerine giriş yaparak başlar ve onlara algoritmaların temelini anlatır. İlk haftalarda, akış şemalarının oluşturulması ve algoritma yazımı üzerinde durulur. Ardından, Python programlama dilinin temel kavramları, kurulum süreci ve geliştirme ortamları tanıtılır. Dersin ilerleyen haftalarında, temel programlama kavramlarına, kontrol yapılarına, fonksiyonlara ve veri yapılarına odaklanılır. Öğrenciler, Python'daki string işlemleri, döngüler, listeler, demetler, sözlükler gibi temel yapıları öğrenir ve uygularlar. Ders, vize ve final sınavları ile desteklenen bir değerlendirme sürecini içerir. Bu süreç boyunca, öğrencilerin teorik bilgileri pratik uygulamalarla pekiştirmeleri ve yazılım geliştirmede temel bir yetkinlik kazanmaları hedeflenir.
#
# (**Course Content:** The "Introduction to Programming - 1" course begins with an introduction to computer science and an explanation of the fundamentals of algorithms. In the initial weeks, emphasis is placed on creating flowcharts and writing algorithms. Subsequently, the basic concepts of the Python programming language, its installation process, and development environments are introduced. As the course progresses, focus shifts to fundamental programming concepts, control structures, functions, and data structures. Students learn and apply basic structures in Python, such as string operations, loops, lists, tuples, and dictionaries. The course includes a review process supported by mid-term and final exams. Throughout this process, the goal is for students to reinforce their theoretical knowledge through practical applications and to acquire fundamental competencies in software development.)
#
# ## Ders Planı
# ### Hafta 1: Giriş ve Bilgisayar Bilimlerine Genel Bakış
# - Dersin Amacı ve İçeriği
# - Bilgisayar Bilimlerine Giriş
# - Yazılım mühendisliği ve bilgisayar bilimlerinin önemi
# - Programlamanın temel kavramları
# - Dersin genel hedefleri ve beklentiler
#
# ### Hafta 2: Algoritma Temelleri ve Akış Şemaları - Bölüm 1
# - Algoritma nedir? Algoritma geliştirmenin temel prensipleri
# - Basit algoritma örnekleri ve algoritma tasarımı
# - Problem çözme yöntemleri ve yaklaşımları
#
# ### Hafta 3: Algoritma Temelleri ve Akış Şemaları - Bölüm 2
# - Akış şemaları: Temel semboller ve akış diyagramlarının oluşturulması
# - Akış şemalarını kullanarak algoritma tasarımı
# - Akış şemaları ile algoritma örneklerinin detaylı incelenmesi
#
# ### Hafta 4: Python Programlama Dilinin Tanıtımı
# - Python programlama dilinin tarihçesi ve özellikleri
# - Python kurulumu ve geliştirme ortamları (IDE'ler)
# - Merhaba Dünya programı ve temel Python sözdizimi
#
# ### Hafta 5: Temel Programlama Kavramları - Bölüm 1
# - Değişkenler, veri tipleri ve atamalar
# - Sayısal ve metinsel ifadeler
# - Basit aritmetik işlemler
#
# ### Hafta 6: Temel Programlama Kavramları - Bölüm 2
# - String işlemleri (dilimleme, metodlar)
# - Standart girdi ve çıktı işlemleri
#
# ### Hafta 7: Koşullu İfadeler
# - Koşullu ifadeler (if, else, elif)
# - Basit kontrol yapısı örnekleri
#
# ### Hafta 8: Vize Haftası
# - İlk 7 haftanın konularını kapsayan vize sınavı
#
# ### Hafta 9: Döngüler - Bölüm 1
# - For döngüsü ve iterasyon
# - Döngüler ile ilgili alıştırmalar ve örnekler
#
# ### Hafta 10: Döngüler - Bölüm 2
# - While döngüsü ve kullanım alanları
# - Döngüler ile ilgili alıştırmalar ve örnekler
#
# ### Hafta 11: Fonksiyonlar - Bölüm 1
# - Fonksiyon tanımlama ve çağırma
# - Parametreler ve geri dönüş değerleri
#
# ### Hafta 12: Fonksiyonlar - Bölüm 2
# - Parametre türleri (konumsal, anahtar kelime)
# - Fonksiyonlar ile ilgili alıştırmalar
#
# ### Hafta 13: Veri Yapıları - Bölüm 1
# - Listeler (List), Demetler (tuple) ve kümeler (set)
# - Tanımlama, erişim, yöntemler
# - Örnekler ve alıştırmalar
#
# ### Hafta 14: Veri Yapıları - Bölüm 2
# - Sözlükler (dictionary): Kullanımı, metodları
# - Veri yapılarının karşılaştırılması ve kullanım senaryoları
# - Karışık veri yapılarına dayalı alıştırmalar
#
# ### Hafta 15-16: Final Sınavı
# - Final Sınavı
# - Dersin Kapanışı ve Değerlendirme
#
# (
# ## Course Plan
# ### Week 1: Introduction and Overview of Computer Science
# - Purpose and Content of the Course
# - Introduction to Computer Science
# - The Importance of Software Engineering and Computer Science
# - Fundamental Concepts of Programming
# - General Objectives and Expectations of the Course
#
# ### Week 2: Fundamentals of Algorithms and Flowcharts - Part 1
# - What is an Algorithm? Basic Principles of Algorithm Development
# - Simple Algorithm Examples and Algorithm Design
# - Problem-Solving Methods and Approaches
#
# ### Week 3: Fundamentals of Algorithms and Flowcharts - Part 2
# - Flowcharts: Basic Symbols and Creation of Flow Diagrams
# - Designing Algorithms Using Flowcharts
# - Detailed Examination of Algorithm Examples with Flowcharts
#
# ### Week 4: Introduction to the Python Programming Language
# - History and Features of the Python Programming Language
# - Python Installation and Development Environments (IDEs)
# - Hello World Program and Basic Python Syntax
#
# ### Week 5: Basic Programming Concepts - Part 1
# - Variables, Data Types, and Assignments
# - Numerical and Textual Expressions
# - Simple Arithmetic Operations
#
# ### Week 6: Basic Programming Concepts - Part 2
# - String Operations (slicing, methods)
# - Standard Input and Output Operations
#
# ### Week 7: Conditional Statements
# - Conditional Statements (if, else, elif)
# - Simple Control Structure Examples
#
# ### Week 8: Midterm Week
# - Midterm Exam Covering the Topics of the First 7 Weeks
#
# ### Week 9: Loops - Part 1
# - For Loop and Iteration
# - Exercises and Examples Related to Loops
#
# ### Week 10: Loops - Part 2
# - While Loop and Its Applications
# - Exercises and Examples Related to Loops
#
# ### Week 11: Functions - Part 1
# - Defining and Calling Functions
# - Parameters and Return Values
#
# ### Week 12: Functions - Part 2
# - Types of Parameters (positional, keyword)
# - Exercises Related to Functions
#
# ### Week 13: Data Structures - Part 1
# - Lists, Tuples, and Sets
# - Definition, Access, Methods
# - Examples and Exercises
#
# ### Week 14: Data Structures - Part 2
# - Dictionaries: Usage, Methods
# - Comparison of Data Structures and Use Cases
# - Exercises Based on Mixed Data Structures
#
# ### Weeks 15-16: Final Exam
# - Final Exam
# - Course Closure and Evaluation
# )
# ---
#
# **Öğrenme Çıktıları**
#
# 1. **Problem Çözme Yeteneği:** Öğrenciler, bilgisayar bilimlerinin temel prensiplerini kullanarak problemleri tanımlama, analiz etme ve çözme yeteneğine sahip olacaklardır. Bu süreç, problemin kritik noktalarını belirleme, problemleri mantıksal birimlere bölme ve her bir birim için etkili algoritmalar geliştirme becerilerini içerir.
#
# 2. **Algoritma Geliştirme ve Akış Şemaları:** Öğrenciler, verilen bir problem için gerekli algoritmayı düşünebilir, tasarlar ve bu algoritmaları akış şemalarına dönüştürebilirler. Ayrıca, oluşturulan akış şemalarını test ederek potansiyel hataları belirleyebilir ve giderme yöntemlerini uygulayabilirler.
#
# 3. **Programlama Dili ve Ortamı Becerileri:** Öğrenciler, bir programlama dili ortamını etkin bir şekilde kullanma becerisine sahip olacaklar. Bu beceriler, kod yazma, hata ayıklama ve programın çalıştırılması gibi temel işlemleri içerir. Ayrıca, programlama sırasında ortaya çıkabilecek sözdizimi hatalarını tespit etme ve düzeltme yeteneği kazanacaklardır.
#
# 4. **Değişkenler ve Kontrol Yapıları:** Öğrenciler, bir programın kodlanabilmesi için gereken değişkenleri tanımlama, kontrol deyimlerini ve döngüleri uygun yerlerde kullanma becerisine sahip olacaklardır. Bu, programın hem etkinlik hem de verimlilik açısından en uygun şekilde kodlanması için gereklidir.
#
# 5. **Kod Yazma ve Test Etme:** Öğrenciler, programların kodlarını yazma ve bu programları çeşitli test senaryoları altında çalıştırma becerisine sahip olacaklar. Ayrıca, oluşabilecek sözdizimi ve mantıksal hataları belirleyebilir ve bunları etkin bir şekilde giderme stratejileri geliştirebilirler.
#
# 6. **Pratik Uygulama ve Problem Çözme:** Öğrenciler, teorik bilgileri pratik uygulamalarla birleştirerek gerçek dünya problemlerine çözümler geliştirme becerisini kazanacaklardır. Bu süreç, algoritma tasarımı, kod geliştirme ve test etme aşamalarını kapsar.
#
# (**Learning Outcomes**
#
# 1. **Problem-Solving Ability:** Students will acquire the ability to identify, analyze, and solve problems using the fundamental principles of computer science. This process involves identifying critical aspects of the problem, dividing problems into logical units, and developing effective algorithms for each unit.
#
# 2. **Algorithm Development and Flowcharts:** Students will be capable of conceptualizing, designing, and transforming algorithms into flowcharts for a given problem. Moreover, they will be able to test the created flowcharts, identify potential errors, and apply correction methods.
#
# 3. **Programming Language and Environment Skills:** Students will gain proficiency in using a programming language environment effectively. These skills include coding, debugging, and executing programs. They will also develop the ability to detect and correct syntax errors that may occur during programming.
#
# 4. **Variables and Control Structures:** Students will master defining variables necessary for coding a program, and using control statements and loops where appropriate. This is essential for coding the program in the most efficient and effective manner possible.
#
# 5. **Code Writing and Testing:** Students will have the ability to write program codes and run these programs under various testing scenarios. They will also be able to identify syntactic and logical errors and develop effective strategies for rectification.
#
# 6. **Practical Application and Problem Solving:** Students will combine theoretical knowledge with practical applications to develop solutions to real-world problems. This process includes algorithm design, code development, and testing phases.
# )
# ---

# %% [markdown]
# ---
#
# ## Programlamaya Giriş Laboratuvarı - I
#
# ### Dersin Amacı:
# "Programlamaya Giriş Laboratuvarı - I" dersi, "Programlamaya Giriş - I" dersinde edinilen teorik bilgileri pekiştirmek ve öğrencilere Python programlama dili ile pratik yapma deneyimi sağlamayı amaçlamaktadır. Laboratuvar seansları, pratik kodlama egzersizleri ve projeleri aracılığıyla öğrencilerin bilgisayar bilimi temellerini, algoritma geliştirme ve problem çözme becerilerini güçlendirmek için tasarlanmıştır. Amaç, öğrencilerin teorik kavramları gerçek dünya senaryolarında uygulayabilmelerini sağlayarak yazılım geliştirme yeteneklerini artırmaktır.
#
# ### Ders İçeriği:
# Laboratuvar dersi, teorik derslerde tartışılan kavramları pratik egzersizler ve projeler aracılığıyla uygulamaya odaklanmaktadır. Her laboratuvar seansı, "Programlamaya Giriş - I" dersinin haftalık konularıyla uyumlu şekilde düzenlenmiştir, böylece öğrenciler öğrendiklerini hemen pratik bir bağlamda uygulayabilirler.
#
# ### Laboratuvar Planı:
# #### 1. Hafta: Python'a Giriş
# - Geliştirme ortamının kurulumu
# - Basit bir "Merhaba Dünya" programı yazma ve çalıştırma
# - Python sözdizimi ve etkileşimli kabuk ile tanışma
#
# #### 2-3. Hafta: Algoritmalar ve Akış Şemaları
# - Sınıfta tartışılan basit algoritmalar için akış şemaları oluşturma
# - Akış şemalarını Python koduna dönüştürme
# - Temel problem çözme egzersizleri
#
# #### 4-5. Hafta: Değişkenler, Veri Tipleri ve Operatörler
# - Değişkenler, veri tipleri ve operatörlerle ilgili pratik egzersizler
# - Sayısal ve metinsel ifadeler üzerine interaktif oturumlar
# - Python'da basit aritmetik işlemleri gerçekleştirme
#
# #### 6-7. Hafta: Kontrol Yapıları
# - Python'da koşullu ifadelerin (if, else, elif) uygulanması
# - Basit kontrol yapıları oluşturma egzersizleri
#
# #### 8. Hafta: Ara Proje
# - 1-7. haftalarda ele alınan konuları kapsayan küçük bir proje, öğrenilen kavramları pekiştirme
#
# #### 9-10. Hafta: Döngüler
# - For ve while döngüleri üzerine pratik egzersizler
# - Döngü tabanlı problem çözme oturumları
#
# #### 11-12. Hafta: Fonksiyonlar
# - Python'da fonksiyon tanımlama ve çağırma
# - Parametre geçişi ve geri dönüş değerleri
# - Yeniden kullanılabilir kod blokları yazma
#
# #### 13-14. Hafta: Veri Yapıları
# - Listeler, demetler, kümeler ve sözlüklerle çalışma
# - Veri manipülasyonu ve erişim yöntemleri
# - Pratik problem çözme için veri yapılandırma
#
# #### 15-16. Hafta: Final Projesi
# - Kurs boyunca öğrenilen tüm kavramları kullanmayı gerektiren kapsamlı bir proje
# - Proje sunumu ve değerlendirme
#
# ### Öğrenme Çıktıları:
# Bu laboratuvar dersini tamamlayan öğrenciler;
# - Python kullanarak programlamanın temel prensipleri ve algoritma geliştirme konularını uygulayabilecek,
# - Teorik algoritmaları ve akış şemalarını çalışır Python kodlarına dönüştürebilecek,
# - Kontrol yapıları, döngüler, fonksiyonlar ve veri yapıları kullanarak pratik problemleri çözebilecek,
# - Çeşitli programlama kavramlarını entegre ederek küçük ve orta ölçekli projeler geliştirebilecek,
# - Python programlarını etkin bir şekilde hata ayıklayıp test edebileceklerdir.
#
# ---
# ## Introduction to Programming Laboratory - I
#
# ### Course Objective:
# The "Introduction to Programming Laboratory - I" course aims to complement the theoretical knowledge acquired in "Introduction to Programming - I" by providing hands-on experience with Python programming. The laboratory sessions are designed to reinforce students' understanding of computer science fundamentals, algorithm development, and problem-solving skills through practical coding exercises and projects. The objective is to enable students to apply theoretical concepts in real-world scenarios, thereby enhancing their software development capabilities.
#
# ### Course Content:
# The laboratory course focuses on applying the concepts discussed in the theoretical lectures through practical exercises and projects. Each lab session is aligned with the weekly topics of the "Introduction to Programming - I" course, ensuring that students can immediately apply what they have learned in a practical context.
#
# ### Lab Plan:
# #### Week 1: Getting Started with Python
# - Setting up the development environment
# - Writing and executing a simple "Hello World" program
# - Introduction to basic Python syntax and interactive shell
#
# #### Week 2-3: Algorithms and Flowcharts
# - Creating flowcharts for simple algorithms discussed in class
# - Translating flowcharts into Python code
# - Basic problem-solving exercises
#
# #### Week 4-5: Variables, Data Types, and Operators
# - Hands-on exercises with variables, data types, and operators
# - Interactive sessions on numerical and textual expressions
# - Implementing simple arithmetic operations in Python
#
# #### Week 6-7: Control Structures
# - Implementing conditional statements (if, else, elif) in Python
# - Exercises on building simple control structures
#
# #### Week 8: Midterm Project
# - A small project covering topics from Weeks 1 to 7, reinforcing learned concepts
#
# #### Week 9-10: Loops
# - Practical exercises on for and while loops
# - Loop-based problem-solving sessions
#
# #### Week 11-12: Functions
# - Defining and calling functions in Python
# - Parameter passing and return values
# - Writing reusable code blocks
#
# #### Week 13-14: Data Structures
# - Working with lists, tuples, sets, and dictionaries
# - Data manipulation and access methods
# - Structuring data for practical problem-solving
#
# #### Week 15-16: Final Project
# - A comprehensive project that requires students to utilize all the concepts learned throughout the course
# - Project presentation and review
#
# ### Learning Outcomes:
# By the end of this laboratory course, students will be able to:
# - Apply the basic principles of programming and algorithm development using Python.
# - Translate theoretical algorithms and flowcharts into executable Python code.
# - Solve practical problems by applying control structures, loops, functions, and data structures.
# - Develop small to medium-scale projects by integrating various programming concepts.
# - Debug and test Python programs effectively.
# ---

# %% [markdown]
# ## Programlamaya Giriş - 2
# ### Hafta 1-2: Temel Konuların Tekrarı ve Alıştırmalar
# - **Hafta 1:**
#   - Python programlama dilinde temel kavramların tekrarı: Değişkenler, veri tipleri, temel operatörler
#   - Temel kontrol yapıları: Koşullu ifadeler ve basit döngüler
#   - Kısa alıştırmalar ve örneklerle pekiştirme
#
# - **Hafta 2:**
#   - Fonksiyonlar, parametreler ve geri dönüş değerleri
#   - Listeler, demetler ve sözlükler: Veri yapılarının tekrarı ve ileri düzey kullanımları
#   - Öğrencilerin birinci dönemde öğrendiklerini pekiştirecek pratik alıştırmalar
#
# ### Hafta 3: Nesne Yönelimli Programlama (NYP) - Giriş
# - NYP'nin temel kavramları: Sınıf, nesne, metod, kapsülleme
# - Python'da sınıf tanımlama ve nesne oluşturma
#
# ### Hafta 4: NYP - İleri Konular
# - Kalıtım, polimorfizm ve soyutlama
# - Özel metotlar, sınıf metotları ve statik metotlar
#
# ### Hafta 5: İleri Veri Yapıları
# - Yığınlar (stacks), kuyruklar (queues) ve bağlı listeler (linked lists)
# - Veri yapılarının Python'da uygulanması
#
# ### Hafta 6: Algoritmalar - Sıralama ve Arama
# - Temel sıralama algoritmaları: Kabarcık sıralaması, seçmeli sıralama
# - İkili arama, doğrusal arama
#
# ### Hafta 7: Karmaşıklık Teorisi ve Algoritma Analizi
# - Big O gösterimi, zaman ve mekân karmaşıklığı
# - Algoritma optimizasyonu üzerine tartışma
#
# ### Hafta 8: Vize Haftası
#
# ### Hafta 9: Veritabanı Yönetimi
# - SQL temelleri: SELECT, INSERT, UPDATE, DELETE
# - Python ile SQLite kullanımı
#
# ### Hafta 10: Dosya İşlemleri ve İstisna Yönetimi
# - Dosya okuma/yazma işlemleri, JSON ve XML işlemleri
# - İleri düzey istisna yönetimi teknikleri
#
# ### Hafta 11: Grafik Kullanıcı Arayüzü (GUI) Programlama
# - Tkinter ile basit GUI uygulamaları geliştirme
# - Event-driven programlama
#
# ### Hafta 12: Web Programlama Temelleri
# - Flask/Django ile basit web uygulamaları geliştirme
# - HTML, CSS ve Jinja2 şablonları
#
# ### Hafta 13: Ağ Programlama
# - Soket programlama temelleri
# - Basit bir sohbet uygulaması geliştirme
#
# ### Hafta 14: Multithreading ve Multiprocessing
# - Python'da iş parçacığı (threading) ve süreç (multiprocessing) kullanımı
# - Asenkron programlama
#
# ### Hafta 15: Test Driven Development (TDD) ve Yazılım Testi
# - Test odaklı geliştirme, birim testleri yazma
# - Python'da `unittest` modülünün kullanımı
#
# ### Hafta 16: Proje Haftası ve Final Sınavı
# - Dönem boyunca öğrenilen konuları kapsayan bir proje geliştirme
# - Proje sunumları ve değerlendirme
# - Final sınavı
# ---

# %% [markdown]
# ### Hafta 1: Giriş ve Bilgisayar Bilimlerine Genel Bakış
# - Programlamanın temel kavramları
# - Yazılım mühendisliği ve bilgisayar bilimlerinin önemi
# - Dersin genel hedefleri ve beklentiler
#
# ### Hafta 2: Algoritma Temelleri ve Akış Şemaları
# - Algoritma nedir? Algoritma geliştirmenin temel prensipleri
# - Akış şemaları: Temel semboller ve akış diyagramlarının oluşturulması
# - Basit algoritma örneklerinin akış şemaları ile gösterimi
#
# ### Hafta 3: Python Programlama Dilinin Tanıtımı
# - Python programlama dilinin tarihçesi ve özellikleri
# - Python kurulumu ve geliştirme ortamları (IDE'ler)
# - Merhaba Dünya programı ve temel Python sözdizimi
#
# ### Hafta 4: Değişkenler, Veri Tipleri ve İfadeler
# - Değişkenler ve veri tipleri
# - Sayısal ve metinsel ifadeler
# - Basit girdi/çıktı işlemleri
# - Atama, karşılaştırma ve mantıksal öperatörler
#
# ### Hafta 5: Koşullu İfadeler
# - `if`, `elif`, ve `else` kullanımı
# - Mantıksal operatörler
# - Koşullu ifadelerle problem çözme
#
# ### Hafta 6: Döngüler
# - `for` döngüsü ve iterasyon
# - `while` döngüsü ve kullanım alanları
# - Döngülerle algoritma geliştirme
#
# ### Hafta 7: Fonksiyonlar ve Modüller
# - Fonksiyon tanımlama ve çağırma
# - Parametreler ve dönüş değerleri
# - Modüller ve kendi modüllerimizi yazma
#
# ### Hafta 8: Veri Yapıları (1) - Listeler ve Demetler
# - Listeler: Tanımlama, erişim, dilimleme ve yöntemler
# - Demetler: Tanımlama ve kullanım alanları
# - Liste ve demetlerle çalışmak
#
# ### Hafta 9: Veri Yapıları (2) - Sözlükler ve Kümeler
# - Sözlükler: Tanımlama, erişim ve yöntemler
# - Kümeler: Tanımlama ve kullanım alanları
# - Veri yapılarının karşılaştırılması
#
#
#
# ### Hafta 13: Dersin Gözden Geçirilmesi ve Final Sınavına Hazırlık
# - Önceki haftalarda öğrenilen konuların gözden geçirilmesi
# - Öğrencilerin soru ve cevapları
# - Final sınavına hazırlık ipuçları ve stratejileri
#
# Bu ders planı, öğrencilere programlamaya giriş ve Python programlama dilinin temellerini sağlam bir şekilde öğretmeyi hedefler. Her hafta, belirli bir konunun derinlemesine anlaşılmasını ve pratiğe dökülmesini sağlayacak şekilde tasarlanmıştır.

# %% [markdown]
# ## Öğrenme Çıktıları:
#
# Elbette, her hafta için belirlenen öğrenme çıktılarını Türkçe ve İngilizce olarak aşağıda sunuyorum:
#
# ### Hafta 1: Giriş ve Temel Kavramlar
#  Öğrenciler dersin amacını, içeriğini ve bilgisayar bilimlerinin temel kavramlarını anlarlar. Algoritmaların temellerini ve akış şemalarının nasıl oluşturulacağını öğrenirler.
# (Students will understand the purpose and content of the course, as well as the fundamental concepts of computer science. They will learn the basics of algorithms and how to create flowcharts.)
#
# ### Hafta 2: Algoritmalar ve Akış Şemaları
#  Öğrenciler, akış şemalarında karar yapılarını ve basit algoritma örneklerini kavrarlar. Algoritma yazma pratiği yaparlar.
# (Students will grasp decision structures in flowcharts and examples of simple algorithms. They will practice writing algorithms.)
#
# ### Hafta 3: Python'a Giriş ve Kurulum
#  Öğrenciler, Python programlama dilinin tarihçesini ve önemini anlar, kurulumunu ve geliştirme ortamlarını öğrenirler.
# (Students will understand the history and significance of the Python programming language, and learn about its installation and development environments.)
#
# ### Hafta 4: Temel Programlama Kavramları - Bölüm 1
#  Öğrenciler, değişkenleri, veri tiplerini ve Python'da basit aritmetik ve string işlemlerini öğrenirler.
# (Students will learn about variables, data types, and basic arithmetic and string operations in Python.)
#
# ### Hafta 5: Temel Programlama Kavramları - Bölüm 2
#  Öğrenciler, Python'da string işlemlerini, standart girdi ve çıktı işlemlerini ve temel hata ayıklama tekniklerini öğrenirler.
# (Students will learn string operations, standard input and output operations, and basic debugging techniques in Python.)
#
# ### Hafta 6: Kontrol Yapıları - Bölüm 1
#  Öğrenciler, Python'da koşullu ifadeleri (if, else, elif) ve basit kontrol yapıları örneklerini öğrenirler.
# (Students will learn conditional statements (if, else, elif) in Python and examples of simple control structures.)
#
# ### Hafta 7: Kontrol Yapıları - Bölüm 2
#  Öğrenciler, Python'da döngü yapılarını (while, for) ve bu yapılarla ilgili alıştırmaları öğrenirler.
# (Students will learn loop structures (while, for) in Python and practice exercises related to these structures.)
#
# ### Hafta 8: Vize Haftası
#  Öğrenciler, ilk 7 haftanın konularını kapsayan bir sınavda bilgilerini değerlendirirler.
# (Students will assess their knowledge in an exam covering the topics of the first 7 weeks.)
#
# ### Hafta 9: Fonksiyonlar - Bölüm 1
#  Öğrenciler, Python'da fonksiyon tanımlamanın ve çağırmanın temellerini öğrenirler.
# (Students will learn the basics of defining and calling functions in Python.)
#
# ### Hafta 10: Fonksiyonlar - Bölüm 2
#  Öğrenciler, Python'da parametre türlerini ve fonksiyonlarla ilgili alıştırmaları öğrenirler.
# (Students will learn about parameter types in Python and practice exercises related to functions.)
#
# ### Hafta 11: Veri Yapıları - Bölüm 1
#  Öğrenciler, Python'da listeler, demetler ve kümeler ile bunların tanımlanması, erişimi ve yöntemlerini öğrenirler.
# (Students will learn about lists, tuples, and sets in Python, including their definition, access, and methods.)
#
# ### Hafta 12: Veri Yapıları - Bölüm 2
#  Öğrenciler, Python'da sözlüklerin kullanımını, metodlarını ve veri yapılarının karşılaştırılmasını öğrenirler.
# (Students will learn the use and methods of dictionaries in Python, and the comparison of data structures.)
#
# ### Hafta 13: Modüller ve Kütüphaneler
#  Öğrenciler, Python'da modüllerin kullanımını ve standart kütüphane modüllerini öğrenirler.
# (Students will learn the use of modules in Python and about standard library modules.)
#
# ### Hafta 14: Düzenli İfadeler (Regex)
#  Öğrenciler, düzenli ifadelerin temel kavramlarını ve Python'da kullanımını öğrenirler.
# (Students will learn the basic concepts of regular expressions and their use in Python.)
#
# ### Hafta 15-16: Final Sınavı
#  Öğrenciler, tüm dersin konularını kapsayan final sınavında bilgilerini değerlendirirler.
# (Students will assess their knowledge in the final exam covering all the course topics.)
